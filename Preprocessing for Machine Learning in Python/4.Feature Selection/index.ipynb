# %% [markdown]
# # What is feature selection ?
# - Selecting features to be used for modelling
# - Doesn't create new features
# - Improves model's performance
#
# # When to select features
# - Reducing noise
# - Features are strongly statistically correlated
# - Reduce overall variance
#
# # Redundant features
# - Redundant features are unnecessary because they duplicate information already present in other features, often shown by strong correlation or similar meaning. These can arise during feature engineering and can sometimes be identified manually by understanding the dataset. Feature selection is an iterative process — removing features may or may not improve model performance, so choices often need to be reassessed.
#
# # Correlated features
# We should drop features that are highly correlated because they move together and provide redundant information. This is especially important for linear models, which assume features are independent—strong correlations can introduce bias.
# Pearson’s correlation coefficient measures this relationship:
# - Close to 1 → strong positive correlation (move in same direction)
# - Close to 0 → little or no correlation
# - Close to -1 → strong negative correlation (move in opposite directions)
# - We can compute Pearson correlation for all feature pairs using pandas to identify highly correlated features.

# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)
hiking = pd.read_json("../7.Resources/hiking.json")
wine = pd.read_csv('../7.Resources/wine_types.csv')
volunteer = pd.read_csv("../7.Resources/volunteer_opportunities.csv")

# %%
# volunteer.corr()
volunteer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   opportunity_id      665 non-null    int64
#  1   content_id          665 non-null    int64
#  2   vol_requests        665 non-null    int64
#  3   event_time          665 non-null    int64
#  4   title               665 non-null    str
#  5   hits                665 non-null    int64
#  6   summary             665 non-null    str
#  7   is_priority         62 non-null     str
#  8   category_id         617 non-null    float64
#  9   category_desc       617 non-null    str
#  10  amsl                0 non-null      float64
#  11  amsl_unit           0 non-null      float64
#  12  org_title           665 non-null    str
#  13  org_content_id      665 non-null    int64
#  14  addresses_count     665 non-null    int64
#  15  locality            595 non-null    str
# ...

# %%
wine.corr()
# Out:
#                               Type  Alcohol  Malic acid   Ash  \
# Type                          1.00    -0.33        0.44 -0.05
# Alcohol                      -0.33     1.00        0.09  0.21
# Malic acid                    0.44     0.09        1.00  0.16
# Ash                          -0.05     0.21        0.16  1.00
# Alcalinity of ash             0.52    -0.31        0.29  0.44
# Magnesium                    -0.21     0.27       -0.05  0.29
# Total phenols                -0.72     0.29       -0.34  0.13
# Flavanoids                   -0.85     0.24       -0.41  0.12
# Nonflavanoid phenols          0.49    -0.16        0.29  0.19
# Proanthocyanins              -0.50     0.14       -0.22  0.01
# Color intensity               0.27     0.55        0.25  0.26
# Hue                          -0.62    -0.07       -0.56 -0.07
# OD280/OD315 of diluted wines -0.79     0.07       -0.37  0.00
# Proline                      -0.63     0.64       -0.19  0.22
#
# ...

# %% [markdown]
# # Scalling features using text vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = hiking['Location']

tfidf_vec = TfidfVectorizer()
text_tfidf = tfidf_vec.fit_transform(documents)

print(tfidf_vec.vocabulary_)

print(text_tfidf[3].data)

print(text_tfidf[3].indices)
# Out:
# {'enter': 31, 'behind': 14, 'the': 102, 'salt': 93, 'marsh': 63, 'nature': 69, 'center': 20, 'located': 59, 'near': 70, 'intersection': 52, 'of': 73, 'east': 29, '33rd': 2, 'street': 100, 'and': 5, 'avenue': 10, 'park': 80, 'at': 8, 'lincoln': 58, 'road': 90, 'ocean': 72, 'entrance': 32, 'trails': 106, 'begin': 13, 'or': 76, 'are': 7, 'prospect': 86, 'audubon': 9, 'wide': 116, 'check': 21, 'out': 78, 'our': 77, 'href': 48, 'features': 35, 'hiking': 44, 'alley': 4, 'pond': 85, 'page': 79, 'for': 38, 'map': 62, 'directions': 27, 'to': 103, 'scenic': 94, 'locations': 60, 'forest': 39, 'drive': 28, 'off': 74, 'woodhaven': 118, 'boulevard': 16, 'memorial': 64, 'metropolitan': 65, 'francis': 40, 'lewis': 56, 'union': 109, 'turnpike': 108, 'brielle': 17, 'roanoake': 91, 'rockland': 92, 'avenues': 11, 'richmond': 89, 'st': 97, 'patrick': 83, 'place': 84, 'mid': 66, 'way': 114, 'trailhead': 105, 'reidel': 88, 'hill': 45, 'mulberry': 68, 'travis': 107, 'limited': 57, 'parking': 81, 'willowbroo
# ...

# %% [markdown]
# # Looking at word weights

# %%
vocab = {v:k for k,v in tfidf_vec.vocabulary_.items()}
print(vocab)

zipped_row = dict(zip(text_tfidf[3].data,text_tfidf[3].indices))
print(zipped_row)
# Out:
# {31: 'enter', 14: 'behind', 102: 'the', 93: 'salt', 63: 'marsh', 69: 'nature', 20: 'center', 59: 'located', 70: 'near', 52: 'intersection', 73: 'of', 29: 'east', 2: '33rd', 100: 'street', 5: 'and', 10: 'avenue', 80: 'park', 8: 'at', 58: 'lincoln', 90: 'road', 72: 'ocean', 32: 'entrance', 106: 'trails', 13: 'begin', 76: 'or', 7: 'are', 86: 'prospect', 9: 'audubon', 116: 'wide', 21: 'check', 78: 'out', 77: 'our', 48: 'href', 35: 'features', 44: 'hiking', 4: 'alley', 85: 'pond', 79: 'page', 38: 'for', 62: 'map', 27: 'directions', 103: 'to', 94: 'scenic', 60: 'locations', 39: 'forest', 28: 'drive', 74: 'off', 118: 'woodhaven', 16: 'boulevard', 64: 'memorial', 65: 'metropolitan', 40: 'francis', 56: 'lewis', 109: 'union', 108: 'turnpike', 17: 'brielle', 91: 'roanoake', 92: 'rockland', 11: 'avenues', 89: 'richmond', 97: 'st', 83: 'patrick', 84: 'place', 66: 'mid', 114: 'way', 105: 'trailhead', 88: 'reidel', 45: 'hill', 68: 'mulberry', 107: 'travis', 57: 'limited', 81: 'parking', 117: 'willo
# ...

# %%
def return_weights(vocab,vector,vector_index):
    zipped = dict(zip(vector[vector_index].indices,vector[vector_index].data))
    return {vocab[i]:zipped[i] for i in vector[vector_index].indices}

print(return_weights(vocab,text_tfidf,3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 5
#       2     zipped = dict(zip(vector[vector_index].indices,vector[vector_index].data))
#       3     return {vocab[i]:zipped[i] for i in vector[vector_index].indices}
# ----> 5 print(return_weights(vocab,text_tfidf,3).json())
#
# AttributeError: 'dict' object has no attribute 'json'
